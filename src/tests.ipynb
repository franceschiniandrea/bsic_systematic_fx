# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('../data/fx_data.xlsx')

# %%
data.head()
# Out:
#              LON Fixes                Unnamed: 1                Unnamed: 2  \
# 0                 Date  AUDUSD CMPL Curncy  (R1)  USDCAD CMPL Curncy  (L1)
# 1  2023-11-15 00:00:00                    0.6505                    1.3699
# 2  2023-11-14 00:00:00                    0.6495                    1.3714
# 3  2023-11-13 00:00:00                    0.6384                    1.3791
# 4  2023-11-10 00:00:00                    0.6357                     1.381
#
#                  Unnamed: 3  Unnamed: 4                Unnamed: 5  \
# 0  USDCHF CMPL Curncy  (R3)         NaN  EURUSD CMPL Curncy  (R2)
# 1                    0.8889      6.8700                    1.0857
# 2                    0.8903      6.8603                    1.0873
# 3                     0.902      6.9738                    1.0696
# 4                    0.9024      6.9832                    1.0679
#
#                  Unnamed: 6                Unnamed: 7  \
# 0  GBPUSD CMPL Curncy  (L2)  USDJPY CMPL Curncy  (R1)
# ...
