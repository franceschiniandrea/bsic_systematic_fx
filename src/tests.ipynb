# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('../data/fx_data.xlsx', header=[0,1], index_col=[0,1])
london_fix = pd.read_excel('../data/FX_Fixes.xlsx', sheet_name='LON_Fix', index_col=0, parse_dates=True)
ny_fix = pd.read_excel('../data/FX_Fixes.xlsx', sheet_name='NY_Fix', index_col=0, parse_dates=True)

# %%
london_fix.columns = [col.split()[0] for col in london_fix.columns]
ny_fix.columns = [col.split()[0] for col in ny_fix.columns]
# Out:
#             AUDUSD CMPN Curncy  (L1)  USDCAD CMPN Curncy  (R2)  \
# Date
# 2023-11-15                    0.6506                    1.3703
# 2023-11-14                    0.6507                    1.3693
# 2023-11-13                    0.6377                    1.3805
# 2023-11-10                    0.6361                    1.3800
# 2023-11-09                    0.6367                    1.3808
# ...                              ...                       ...
# 2000-01-07                    0.6549                    1.4558
# 2000-01-06                    0.6533                    1.4599
# 2000-01-05                    0.6579                    1.4500
# 2000-01-04                    0.6550                    1.4528
# 2000-01-03                    0.6585                    1.4468
#
#             USDCHF CMPN Curncy  (L3)  USDDKK CMPN Curncy  (R4)  \
# Date
# 2023-11-15                    0.8889                    6.8725
# 2023-11-14                    0.8891                    6.8566
# ...
