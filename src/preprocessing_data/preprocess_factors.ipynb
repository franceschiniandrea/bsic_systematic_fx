# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fx_data = pd.read_excel('../data/fx_fixes.xlsx', sheet_name='LON_Fix', index_col=0)
fx_data = fx_data.pct_change()
fx_data['mkt'] = fx_data.mean(axis=1)
fx_data = fx_data['mkt']

# %%
factors = ['momentum', 'value', 'carry'] 
factorsdf = []
for factor in factors: 
    df = pd.read_excel('../data/factors_data.xlsx', sheet_name=factor, index_col=0)
    df.index = pd.to_datetime(df.index)
    factorsdf.append(df)

# %%
df = pd.concat(factorsdf, axis=1)
df.sort_index(inplace=True)
df.ffill(inplace=True)
df = df.reindex(factorsdf[1].index, method="ffill")

# %%
df = pd.concat(factorsdf, axis=1)
df.sort_index(inplace=True)
df.ffill(inplace=True)
df = df.reindex(factorsdf[1].index, method='ffill')
df.head()
# Out:
#             Citi Momentum FX Index  FX Value Index Barclays (G10)  \
# Date
# 2023-11-20                 3120.55                       223.0863
# 2023-11-17                 3120.55                       223.0863
# 2023-11-16                 3117.17                       223.1735
# 2023-11-15                 3117.17                       222.3392
# 2023-11-14                 3117.17                       222.7197
#
#             Bloomberg FX Carry Index
# Date
# 2023-11-20                   238.001
# 2023-11-17                   238.001
# 2023-11-16                   238.780
# 2023-11-15                   239.679
# 2023-11-14                   239.348

# %%
factorsdf = df.sort_index()

# %%
pnl = pd.read_csv('../pnl.csv', index_col=0)
pnl.index = pd.to_datetime(pnl.index)
pnl = pnl.resample('d').sum()
pnl.index = pnl.index.map(lambda x: x.tz_localize(None))
pnl.sort_index(inplace=True)

pnl.tail()
# Out:
#                  AUDUSD       DKKUSD       EURUSD  GBPUSD       NZDUSD  \
# Date
# 2023-11-11     0.000000     0.000000     0.000000     0.0     0.000000
# 2023-11-12     0.000000     0.000000     0.000000     0.0     0.000000
# 2023-11-13    45.713872  -895.124082   -27.873224     0.0   825.329746
# 2023-11-14  3458.249765  1362.838472 -2012.430037     0.0 -6052.342819
# 2023-11-15   -15.266279   754.569434  -147.017478     0.0    40.990795
#
#                  CADUSD  CHFUSD  JPYUSD       NOKUSD       SEKUSD  \
# Date
# 2023-11-11     0.000000     0.0     0.0     0.000000     0.000000
# 2023-11-12     0.000000     0.0     0.0     0.000000     0.000000
# 2023-11-13    15.875724     0.0     0.0   630.172237  1054.569104
# 2023-11-14 -1108.599463     0.0     0.0  1215.470771  4247.401313
# 2023-11-15   -23.108017     0.0     0.0   391.441022  -134.980608
#
#                   total  total_pct
# Date
# 2023-11-11     0.000000   0.000000
# 2023-11-12     0.000000   0.000000
# 2023-11-13  1648.663377   0.001649
# 2023-11-14  1110.588002   0.001111
# 2023-11-15   866.628868   0.000867

# %%
pnl['total'].cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# factorsdf = factorsdf.reindex(pnl.index, method='ffill')
pnl = pnl.reindex(factorsdf.index, method='ffill')
factorsdf = factorsdf.pct_change()

# %%
pnl_pct = pnl['total_pct']
data = pd.concat([pnl_pct, factorsdf], axis=1)
data.columns = ["strategy_returns", "momentum", "value", "carry"]
data = data.merge(fx_data, left_index=True, right_index=True)
data.sort_index(inplace=True)

# %%
data.corr()
data.to_excel('factors_analysis.xlsx')

# %%
from statsmodels.api import OLS
import statsmodels.api as sm

# %%
data['strategy_returns']
# Out:
# Date
# 2002-01-25    0.001816
# 2002-01-28    0.001155
# 2002-01-29   -0.003047
# 2002-01-30   -0.000708
# 2002-01-31    0.001055
#                 ...
# 2023-11-09   -0.002107
# 2023-11-10    0.001515
# 2023-11-13    0.001649
# 2023-11-14    0.001111
# 2023-11-15    0.000867
# Name: strategy_returns, Length: 5359, dtype: float64

# %%
plt.hist(data['strategy_returns'], bins=50, density=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\andre\projects\python\bsic_systematic_fx\src\preprocess_factors.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/andre/projects/python/bsic_systematic_fx/src/preprocess_factors.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> plt.hist(data['strategy_returns'], bins=50, density=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/projects/python/bsic_systematic_fx/src/preprocess_factors.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> plt.kdeplot(data['strategy_returns'])
#
# NameError: name 'plt' is not defined

# %%
X = data[['mkt', 'carry', 'value']]
X = sm.add_constant(X)
y = data['strategy_returns']

model = OLS(y, X, missing='drop')
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       strategy_returns   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     21.36
# Date:                Thu, 23 Nov 2023   Prob (F-statistic):           9.49e-14
# Time:                        22:32:08   Log-Likelihood:                 24757.
# No. Observations:                5357   AIC:                        -4.951e+04
# Df Residuals:                    5353   BIC:                        -4.948e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.378e-05   3.26e-05      2.878      0.004    2.99e-05       0.000
# mkt            0.0216      0.020      1.064      0.287      -0.018       0.061
# carry         -0.0440      0.006     -7.679      0.000      -0.055      -0.033
# value          0.0144      0.008      1.823      0.068      -0.001       0.030
# ==============================================================================
# Omnibus:                      642.461   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6852.523
# Skew:                           0.019   Prob(JB):                         0.00
# Kurtosis:                       8.541   Cond. No.                         623.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.regplot(x='mkt', y='strategy_returns', data=data)
# Out:
# <Axes: xlabel='mkt', ylabel='strategy_returns'>

# %%
plt.scatter(data.index, data['strategy_returns'])

# %%
from sklearn.decomposition import PCA

# %%
pnl_pct
# Out:
# Date
# 2002-01-25    0.001816
# 2002-01-28    0.001155
# 2002-01-29   -0.003047
# 2002-01-30   -0.000708
# 2002-01-31    0.001055
#                 ...
# 2023-11-14    0.001111
# 2023-11-15    0.000867
# 2023-11-16    0.000867
# 2023-11-17    0.000867
# 2023-11-20    0.000867
# Name: total_pct, Length: 5362, dtype: float64

# %%
pnl_pct.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
pca = PCA(0.95, whiten=True, svd_solver='full')
pca.fit(pnl.drop(['total', 'total_pct'], axis=1))
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
print(pca.components_)
# Out:
# [0.21421658 0.13829876 0.12697405 0.11266955 0.10443849 0.09137707
#  0.07371716 0.06124312 0.04235025]
# [97694.60160366 78497.01912939 75214.48973513 70851.21586941
#  68214.1258185  63806.16639108 57309.72422729 52236.33166139
#  43438.21815903]
# [[-1.93656685e-01 -1.62227384e-01 -9.74305069e-02 -5.20424883e-02
#   -6.00590769e-02 -3.78188129e-02 -3.92667442e-02  1.31131118e-03
#    9.46970850e-01  1.43678448e-01]
#  [ 1.69565258e-01 -2.54415759e-01 -1.20611946e-01 -1.17879849e-01
#    2.14288541e-02 -1.18598728e-01 -6.05776113e-03 -4.02944908e-02
#   -1.69849113e-01  9.12712127e-01]
#  [ 5.12066940e-01 -6.29949482e-01 -2.55862139e-01  5.06470926e-02
#    4.24464789e-01  7.46934034e-02  1.74313711e-02  4.55157210e-02
#    4.74144160e-02 -2.87310661e-01]
#  [ 3.59668727e-01  4.85575350e-01  1.71863033e-01 -2.73796030e-01
#    4.96712934e-01 -5.03493570e-01  3.23043069e-04  3.80521438e-02
#    1.68921037e-01  1.19129041e-02]
#  [ 6.77060378e-01  1.14215876e-01  1.65720526e-02  1.53189778e-01
#   -6.85899453e-01 -1.15178980e-01  2.44765225e-02  4.61865654e-02
#    1.27804834e-01 -4.48509324e-02]
#  [ 2.14245444e-01  1.72033003e-01  3.55539165e-02 -6.55352696e-01
#   -1.28847737e-02  6.97872119e-01 -3.55534834e-02  2.23898327e-02
#    6.17064457e-02  3.14284447e-02]
#  [-1.68288751e-01 -3.82595284e-01  7.14288194e-02 -6.60931239e-01
#   -3.05027667e-01 -4.55717187e-01  1.20720973e-01 -1.97344336e-02
#   -1.26993420e-01 -2.27062114e-01]
#  [ 7.06330355e-02  1.23874245e-02  1.47781265e-02  4.35327439e-03
#    1.27024430e-02  1.07170235e-02  7.94383400e-03 -9.95736650e-01
#    2.80572433e-02 -4.47457908e-02]
#  [ 3.61652877e-02 -1.84172978e-01  4.50244092e-01  1.15929244e-02
#   -1.12023146e-02 -2.08277863e-02 -8.72415510e-01 -3.53123885e-04
#   -1.37180577e-02 -7.86305513e-03]]
